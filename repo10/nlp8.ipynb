# %%
#google driveとの連携
from google.colab import drive
drive.mount('/content/drive')

#カレントディレクトリの設定
dir_path = '/content/drive/My Drive/Colab Notebooks/repo10/'
import os
os.chdir(dir_path)

#モジュール追加用pathの設定
import sys
sys.path.append('..')

#モジュールのインポート
import numpy as np

print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/repo10

# %% [markdown]
# **Attention**\
# seq2seqの問題点は入力分の長さにかかわらず固定超に変換してしまうこと。そこで、今まではEncoderの最後の隠れ状態だけを利用していたが、全各tr状態ベクトルを利用する。

# %%
class WeightSum:
  def __init__(self):
    self.params, self.grads = [], []
    self.cache = None
  
  def forward(self, hs, a):
    N, T, H = hs.shape

    ar = a.reshape(N, T, 1).repeat(H, axis =2)
    t = hs * ar
    c = np.sum(t, axis=1)
    
    self.cache = (hs, ar)
    return c

  def backward(self, dc):
    hs, ar = self.cache
    N, T, H = hs.shape

    dt = dc.reshape(N, 1, H).repeat(T, axis=1) #sumの逆伝播
    dar = dt * hs
    dhs = dt * ar
    da = np.sum(dar, axis=2)

    return dhs, da

# %%
from common.np import *
from common.layers import Softmax

# %%
class AttentionWeight:
  def __init__(self):
    self.params, self.grads = [], []
    self.softmax = Softmax()
    self.cache = None

  def forward(self, hs, h):
    N, T, H = hs.shape

    hr = h.reshape(N, 1, H).repeat(T, axis=1)
    t = hs * hr
    s = np.sum(t, axis=2)
    a = self.softmax.forward(s)
    
    self.cache = (hs, hr)
    return a

    def backward(self, da):
      hs, hr = self.cache
      N, T, H = hs.shape

      ds = self.softmax.backward(da)
      dt = ds.reshape(N, T, 1).repeat(H, axis=2)
      dhs = dt * hr
      dhr = dt * hs
      dh = np.sum(dhr, sxis=1)

      return dhs, dh

# %%
class Attention:
  def __init__(self):
    self.params, self.grads = [], []
    self.attention_weight_layer = AttentionWeight()
    self.weight_sum_layer = WeightSum()
    self.attention_weight = None
  
  def forward(self, hs, h):
    a = self.attention_weight_layer.forward(hs, h)
    out = self.weight_sum_layer.forward(hs, a)
    self.attention_weight = a
    return out

  def backward(self, dout):
    dhs0, da = self.weight_sum_layer.backward(dout)
    dhs1, dh = self.attention_weight_layer.backward(da)
    dhs = dhs0 + dhs1
    return dhs, dh

# %%
class TumeAttention:
  def __init__(self):
    self.params, self.grads = [], []
    self.layers = None
    self.attention_weights = None
  
  def forward(self, hs_enc, hs_dec):
    N, T, H = hs_dec.shape
    out = np.empty_like(hs_dec)
    self.layers = []
    self.attention_weights = []

    for t in range(T): #全単語
      layer = Attention()
      out[:, t, :] = layer.forward(hs_enc, hs_dec[:, t, :])
      self.layers.append(layer)
      self.attention_weights.append(layer.attention_weight)
    
    return out

  def backward(self, dout):
    N, T, H = dout.shape
    dhs_enc = 0
    dhs_dec = np.empty_like(dout)

    for t in range(T):
      layer = self.layers[t]
      dhs, dh = layer.backward(dout[:, t, :])
      dhs_enc += dhs
      dhs_dec[:, t, :] = dh

    return dhs_enc, dhs_dec

# %%
from common.time_layers import *
from ch07.seq2seq import  Encoder, Seq2seq
from ch08.attention_layer import TimeAttention

# %%
class AttentionEncoder(Encoder):
  def forward(self, xs):
    xs = self.embed.forward
    hs = self.lstm.forward(xs)
    return hs
  
  def backward(self, dhs):
    dout = self.lstm.backward(dhs)
    dout = self.embed.backward(dout)
    return dout

# %%
class AttentionDecoder:
  def __init__(self, vocab_size, wordvec_size, hidden_size):
    V, D, H = vocab_size, wordvec_size, hidden_size
    rn = np.random.randn

    embed_W = (rn(V, D) / 100).astype('f')
    lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
    lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
    lstm_b = np.zeros(4 * H).astype('f')
    affine_W = (rn(2 * H, V) / np.sqrt(2 * H)).astype('f')
    affine_b = np.zeros(V).astype('f')

    self.embed = TimeEmbedding(embed_W)
    self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
    self.attention = TimeAttention()
    self.affine = TimeAffine(affine_W, affine_b)
    layers = [self.embed, self.lstm, self.attention, self.affine]

    self.params, self.grads = [], []
    for layer in layers:
      self.params += layer.params
      self.grads += layer.grads

  #略

# %% [markdown]
# **Atteintionつきseq2seqの学習**

# %%
import numpy as np
from dataset import sequence
from common.optimizer import  Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from ch08.attention_seq2seq import AttentionSeq2seq
from ch07.seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

#反転
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

#ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256
batch_size = 128
max_epoch = 10
max_grad = 5.0

model = AttentionSeq2seq(vocab_size=vocab_size, wordvec_size=wordvec_size, hidden_size=hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
  trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

  correct_num = 0
  for i in range(len(x_test)):
    question, correct = x_test[[i]], t_test[[i]]
    verbose = i < 10
    correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose, is_reverse=True)
  
  acc = float(correct_num) / len(x_test)
  acc_list.append(acc)
  print('val acc %.3f%%' % (acc * 100))

model.save_params()
# Out:
# | epoch 1 |  iter 1 / 351 | time 0[s] | loss 4.08
# | epoch 1 |  iter 21 / 351 | time 16[s] | loss 3.09
# | epoch 1 |  iter 41 / 351 | time 32[s] | loss 1.90
# | epoch 1 |  iter 61 / 351 | time 47[s] | loss 1.72
# | epoch 1 |  iter 81 / 351 | time 62[s] | loss 1.46
# | epoch 1 |  iter 101 / 351 | time 79[s] | loss 1.19
# | epoch 1 |  iter 121 / 351 | time 95[s] | loss 1.14
# | epoch 1 |  iter 141 / 351 | time 110[s] | loss 1.09
# | epoch 1 |  iter 161 / 351 | time 126[s] | loss 1.06
# | epoch 1 |  iter 181 / 351 | time 142[s] | loss 1.04
# | epoch 1 |  iter 201 / 351 | time 158[s] | loss 1.03
# | epoch 1 |  iter 221 / 351 | time 174[s] | loss 1.02
# | epoch 1 |  iter 241 / 351 | time 189[s] | loss 1.02
# | epoch 1 |  iter 261 / 351 | time 204[s] | loss 1.01
# | epoch 1 |  iter 281 / 351 | time 219[s] | loss 1.00
# | epoch 1 |  iter 301 / 351 | time 234[s] | loss 1.00
# | epoch 1 |  iter 321 / 351 | time 249[s] | loss 1.00
# | epoch 1 |  iter 341 / 351 | time 263[s] | loss 1.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1978-08-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1978-08-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1978-08-11
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1978-08-11
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1978-08-11
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1978-08-11
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1978-08-11
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1978-08-11
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1978-08-11
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1978-08-11
# ---
# val acc 0.000%
# | epoch 2 |  iter 1 / 351 | time 0[s] | loss 1.00
# | epoch 2 |  iter 21 / 351 | time 16[s] | loss 1.00
# | epoch 2 |  iter 41 / 351 | time 31[s] | loss 0.99
# | epoch 2 |  iter 61 / 351 | time 47[s] | loss 0.99
# | epoch 2 |  iter 81 / 351 | time 63[s] | loss 0.99
# | epoch 2 |  iter 101 / 351 | time 79[s] | loss 0.99
# | epoch 2 |  iter 121 / 351 | time 94[s] | loss 0.99
# | epoch 2 |  iter 141 / 351 | time 110[s] | loss 0.98
# | epoch 2 |  iter 161 / 351 | time 126[s] | loss 0.98
# | epoch 2 |  iter 181 / 351 | time 140[s] | loss 0.97
# | epoch 2 |  iter 201 / 351 | time 156[s] | loss 0.95
# | epoch 2 |  iter 221 / 351 | time 170[s] | loss 0.94
# | epoch 2 |  iter 241 / 351 | time 185[s] | loss 0.90
# | epoch 2 |  iter 261 / 351 | time 201[s] | loss 0.83
# | epoch 2 |  iter 281 / 351 | time 216[s] | loss 0.74
# | epoch 2 |  iter 301 / 351 | time 231[s] | loss 0.66
# | epoch 2 |  iter 321 / 351 | time 246[s] | loss 0.58
# | epoch 2 |  iter 341 / 351 | time 261[s] | loss 0.46
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 2006-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 2007-08-09
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1983-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 2016-11-08
# ---
# val acc 51.680%
# | epoch 3 |  iter 1 / 351 | time 0[s] | loss 0.35
# | epoch 3 |  iter 21 / 351 | time 15[s] | loss 0.30
# | epoch 3 |  iter 41 / 351 | time 30[s] | loss 0.21
# | epoch 3 |  iter 61 / 351 | time 46[s] | loss 0.14
# | epoch 3 |  iter 81 / 351 | time 61[s] | loss 0.09
# | epoch 3 |  iter 101 / 351 | time 76[s] | loss 0.07
# | epoch 3 |  iter 121 / 351 | time 91[s] | loss 0.05
# | epoch 3 |  iter 141 / 351 | time 106[s] | loss 0.04
# | epoch 3 |  iter 161 / 351 | time 121[s] | loss 0.03
# | epoch 3 |  iter 181 / 351 | time 136[s] | loss 0.03
# | epoch 3 |  iter 201 / 351 | time 151[s] | loss 0.02
# | epoch 3 |  iter 221 / 351 | time 166[s] | loss 0.02
# | epoch 3 |  iter 241 / 351 | time 181[s] | loss 0.02
# | epoch 3 |  iter 261 / 351 | time 196[s] | loss 0.01
# | epoch 3 |  iter 281 / 351 | time 211[s] | loss 0.01
# | epoch 3 |  iter 301 / 351 | time 226[s] | loss 0.01
# | epoch 3 |  iter 321 / 351 | time 241[s] | loss 0.01
# | epoch 3 |  iter 341 / 351 | time 256[s] | loss 0.01
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.900%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 0.01
# | epoch 4 |  iter 21 / 351 | time 16[s] | loss 0.01
# | epoch 4 |  iter 41 / 351 | time 33[s] | loss 0.01
# | epoch 4 |  iter 61 / 351 | time 50[s] | loss 0.01
# | epoch 4 |  iter 81 / 351 | time 66[s] | loss 0.01
# | epoch 4 |  iter 101 / 351 | time 81[s] | loss 0.01
# | epoch 4 |  iter 121 / 351 | time 97[s] | loss 0.00
# | epoch 4 |  iter 141 / 351 | time 112[s] | loss 0.01
# | epoch 4 |  iter 161 / 351 | time 127[s] | loss 0.00
# | epoch 4 |  iter 181 / 351 | time 142[s] | loss 0.00
# | epoch 4 |  iter 201 / 351 | time 158[s] | loss 0.00
# | epoch 4 |  iter 221 / 351 | time 173[s] | loss 0.00
# | epoch 4 |  iter 241 / 351 | time 188[s] | loss 0.00
# | epoch 4 |  iter 261 / 351 | time 203[s] | loss 0.00
# | epoch 4 |  iter 281 / 351 | time 219[s] | loss 0.00
# | epoch 4 |  iter 301 / 351 | time 234[s] | loss 0.00
# | epoch 4 |  iter 321 / 351 | time 249[s] | loss 0.00
# | epoch 4 |  iter 341 / 351 | time 264[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.900%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 5 |  iter 21 / 351 | time 15[s] | loss 0.00
# | epoch 5 |  iter 41 / 351 | time 31[s] | loss 0.00
# | epoch 5 |  iter 61 / 351 | time 46[s] | loss 0.00
# | epoch 5 |  iter 81 / 351 | time 61[s] | loss 0.00
# | epoch 5 |  iter 101 / 351 | time 76[s] | loss 0.00
# | epoch 5 |  iter 121 / 351 | time 92[s] | loss 0.00
# | epoch 5 |  iter 141 / 351 | time 107[s] | loss 0.00
# | epoch 5 |  iter 161 / 351 | time 122[s] | loss 0.00
# | epoch 5 |  iter 181 / 351 | time 137[s] | loss 0.00
# | epoch 5 |  iter 201 / 351 | time 155[s] | loss 0.00
# | epoch 5 |  iter 221 / 351 | time 172[s] | loss 0.00
# | epoch 5 |  iter 241 / 351 | time 188[s] | loss 0.00
# | epoch 5 |  iter 261 / 351 | time 204[s] | loss 0.00
# | epoch 5 |  iter 281 / 351 | time 221[s] | loss 0.00
# | epoch 5 |  iter 301 / 351 | time 242[s] | loss 0.00
# | epoch 5 |  iter 321 / 351 | time 257[s] | loss 0.00
# | epoch 5 |  iter 341 / 351 | time 273[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 99.920%
# | epoch 6 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 6 |  iter 21 / 351 | time 16[s] | loss 0.00
# | epoch 6 |  iter 41 / 351 | time 31[s] | loss 0.00
# | epoch 6 |  iter 61 / 351 | time 47[s] | loss 0.00
# | epoch 6 |  iter 81 / 351 | time 63[s] | loss 0.00
# | epoch 6 |  iter 101 / 351 | time 79[s] | loss 0.00
# | epoch 6 |  iter 121 / 351 | time 94[s] | loss 0.00
# | epoch 6 |  iter 141 / 351 | time 109[s] | loss 0.00
# | epoch 6 |  iter 161 / 351 | time 125[s] | loss 0.00
# | epoch 6 |  iter 181 / 351 | time 141[s] | loss 0.00
# | epoch 6 |  iter 201 / 351 | time 156[s] | loss 0.00
# | epoch 6 |  iter 221 / 351 | time 171[s] | loss 0.00
# | epoch 6 |  iter 241 / 351 | time 187[s] | loss 0.00
# | epoch 6 |  iter 261 / 351 | time 202[s] | loss 0.00
# | epoch 6 |  iter 281 / 351 | time 217[s] | loss 0.00
# | epoch 6 |  iter 301 / 351 | time 232[s] | loss 0.00
# | epoch 6 |  iter 321 / 351 | time 248[s] | loss 0.00
# | epoch 6 |  iter 341 / 351 | time 263[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1994-05-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 2013-08-22
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 2016-01-06
# ---
# val acc 81.040%
# | epoch 7 |  iter 1 / 351 | time 0[s] | loss 0.11
# | epoch 7 |  iter 21 / 351 | time 15[s] | loss 0.03
# | epoch 7 |  iter 41 / 351 | time 32[s] | loss 0.01
# | epoch 7 |  iter 61 / 351 | time 48[s] | loss 0.00
# | epoch 7 |  iter 81 / 351 | time 63[s] | loss 0.00
# | epoch 7 |  iter 101 / 351 | time 84[s] | loss 0.00
# | epoch 7 |  iter 121 / 351 | time 99[s] | loss 0.00
# | epoch 7 |  iter 141 / 351 | time 114[s] | loss 0.00
# | epoch 7 |  iter 161 / 351 | time 129[s] | loss 0.00
# | epoch 7 |  iter 181 / 351 | time 144[s] | loss 0.00
# | epoch 7 |  iter 201 / 351 | time 159[s] | loss 0.00
# | epoch 7 |  iter 221 / 351 | time 175[s] | loss 0.00
# | epoch 7 |  iter 241 / 351 | time 190[s] | loss 0.00
# | epoch 7 |  iter 261 / 351 | time 205[s] | loss 0.00
# | epoch 7 |  iter 281 / 351 | time 220[s] | loss 0.00
# | epoch 7 |  iter 301 / 351 | time 236[s] | loss 0.00
# | epoch 7 |  iter 321 / 351 | time 253[s] | loss 0.00
# | epoch 7 |  iter 341 / 351 | time 269[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 100.000%
# | epoch 8 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 8 |  iter 21 / 351 | time 17[s] | loss 0.00
# | epoch 8 |  iter 41 / 351 | time 34[s] | loss 0.00
# | epoch 8 |  iter 61 / 351 | time 50[s] | loss 0.00
# | epoch 8 |  iter 81 / 351 | time 66[s] | loss 0.00
# | epoch 8 |  iter 101 / 351 | time 83[s] | loss 0.00
# | epoch 8 |  iter 121 / 351 | time 99[s] | loss 0.00
# | epoch 8 |  iter 141 / 351 | time 116[s] | loss 0.00
# | epoch 8 |  iter 161 / 351 | time 132[s] | loss 0.00
# | epoch 8 |  iter 181 / 351 | time 148[s] | loss 0.00
# | epoch 8 |  iter 201 / 351 | time 165[s] | loss 0.00
# | epoch 8 |  iter 221 / 351 | time 181[s] | loss 0.00
# | epoch 8 |  iter 241 / 351 | time 197[s] | loss 0.00
# | epoch 8 |  iter 261 / 351 | time 213[s] | loss 0.00
# | epoch 8 |  iter 281 / 351 | time 228[s] | loss 0.00
# | epoch 8 |  iter 301 / 351 | time 245[s] | loss 0.00
# | epoch 8 |  iter 321 / 351 | time 261[s] | loss 0.00
# | epoch 8 |  iter 341 / 351 | time 277[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 100.000%
# | epoch 9 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 9 |  iter 21 / 351 | time 17[s] | loss 0.00
# | epoch 9 |  iter 41 / 351 | time 34[s] | loss 0.00
# | epoch 9 |  iter 61 / 351 | time 51[s] | loss 0.00
# | epoch 9 |  iter 81 / 351 | time 68[s] | loss 0.00
# | epoch 9 |  iter 101 / 351 | time 85[s] | loss 0.00
# | epoch 9 |  iter 121 / 351 | time 101[s] | loss 0.00
# | epoch 9 |  iter 141 / 351 | time 118[s] | loss 0.00
# | epoch 9 |  iter 161 / 351 | time 135[s] | loss 0.00
# | epoch 9 |  iter 181 / 351 | time 152[s] | loss 0.00
# | epoch 9 |  iter 201 / 351 | time 168[s] | loss 0.00
# | epoch 9 |  iter 221 / 351 | time 185[s] | loss 0.00
# | epoch 9 |  iter 241 / 351 | time 202[s] | loss 0.00
# | epoch 9 |  iter 261 / 351 | time 219[s] | loss 0.00
# | epoch 9 |  iter 281 / 351 | time 236[s] | loss 0.00
# | epoch 9 |  iter 301 / 351 | time 252[s] | loss 0.00
# | epoch 9 |  iter 321 / 351 | time 269[s] | loss 0.00
# | epoch 9 |  iter 341 / 351 | time 285[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 100.000%
# | epoch 10 |  iter 1 / 351 | time 0[s] | loss 0.00
# | epoch 10 |  iter 21 / 351 | time 16[s] | loss 0.00
# | epoch 10 |  iter 41 / 351 | time 31[s] | loss 0.00
# | epoch 10 |  iter 61 / 351 | time 46[s] | loss 0.00
# | epoch 10 |  iter 81 / 351 | time 62[s] | loss 0.00
# | epoch 10 |  iter 101 / 351 | time 78[s] | loss 0.00
# | epoch 10 |  iter 121 / 351 | time 93[s] | loss 0.00
# | epoch 10 |  iter 141 / 351 | time 108[s] | loss 0.00
# | epoch 10 |  iter 161 / 351 | time 124[s] | loss 0.00
# | epoch 10 |  iter 181 / 351 | time 139[s] | loss 0.00
# | epoch 10 |  iter 201 / 351 | time 154[s] | loss 0.00
# | epoch 10 |  iter 221 / 351 | time 169[s] | loss 0.00
# | epoch 10 |  iter 241 / 351 | time 184[s] | loss 0.00
# | epoch 10 |  iter 261 / 351 | time 199[s] | loss 0.00
# | epoch 10 |  iter 281 / 351 | time 214[s] | loss 0.00
# | epoch 10 |  iter 301 / 351 | time 229[s] | loss 0.00
# | epoch 10 |  iter 321 / 351 | time 243[s] | loss 0.00
# | epoch 10 |  iter 341 / 351 | time 258[s] | loss 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc 100.000%

# %% [markdown]
# 実行できた。結果を見ると、epoch1からepoch2にかけて大きく精度が上がっていて、epoch3では99%近くまでになっている。また、epoch6で精度が落ちてしまっている。
